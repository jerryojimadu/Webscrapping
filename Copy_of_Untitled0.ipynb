# %% [markdown]
# **WEB SCRAPPING PROJECT USING PYTHON AND LOAD UNTO CSV**

# %% [markdown]
# This is a Web scrapping project. The Source Website is Book-To-Scrap website. https://books.toscrape.com/ This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning. This project is a replica of a similar project carried out by Pythonology on Youtube.
# Credit: @Pythonology

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
books = []
for i in range(1,51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')

    for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        star = article.find('p')
        star = star['class'][1]
        price = article.find('p', class_='price_color').text
        price = float(price[1:])
        books.append([title, price, star])

# %%
df = pd.DataFrame(books, columns=['Title', 'price', 'Star rating'])
df.head()
# Out:
#                                    Title  price Star rating
# 0                   A Light in the Attic  51.77       Three
# 1                     Tipping the Velvet  53.74         One
# 2                             Soumission  50.10         One
# 3                          Sharp Objects  47.82        Four
# 4  Sapiens: A Brief History of Humankind  54.23        Five

# %%
df.to_csv('books.csv')

# %%
Thank you! I hope you find this helpful.
